# %%
import pandas as pd

import numpy as np

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df.loc[df.AAA >= 5, 'BBB'] = -1

df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   -1   50
# 2    6   -1  -30
# 3    7   -1  -50

# %%
df.loc[df.AAA >= 5, ['BBB', 'CCC']] = 555

df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5  555  555
# 2    6  555  555
# 3    7  555  555

# %%
df.loc[df.AAA < 5, ['BBB', 'CCC']] = 2000

df
# Out:
#    AAA   BBB   CCC
# 0    4  2000  2000
# 1    5   555   555
# 2    6   555   555
# 3    7   555   555

# %%
df_mask = pd.DataFrame({'AAA': [True] * 4,
                        'BBB': [False] * 4,
                        'CCC': [True, False] * 2})

df_mask
# Out:
#     AAA    BBB    CCC
# 0  True  False   True
# 1  True  False  False
# 2  True  False   True
# 3  True  False  False

# %%
df.where(df_mask, -1000)
# Out:
#    AAA   BBB   CCC
# 0    4 -1000  2000
# 1    5 -1000 -1000
# 2    6 -1000   555
# 3    7 -1000 -1000

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df['logic'] = np.where(df['AAA'] > 5, 'high', 'low')

df
# Out:
#    AAA  BBB  CCC logic
# 0    4   10  100   low
# 1    5   20   50   low
# 2    6   30  -30  high
# 3    7   40  -50  high

# %% [markdown]
# # Splitting

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df[df.AAA <= 5]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50

# %%
df[df.AAA > 5]
# Out:
#    AAA  BBB  CCC
# 2    6   30  -30
# 3    7   40  -50

# %% [markdown]
# # Building criteria

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df.loc[(df['BBB'] < 25) & (df['CCC'] >= -40), 'AAA']
# Out:
# 0    4
# 1    5
# Name: AAA, dtype: int64

# %%
df.loc[(df['BBB'] > 25) | (df['CCC'] >= -40), 'AAA']
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# Name: AAA, dtype: int64

# %%
df.loc[(df['BBB'] > 25) | (df['CCC'] >= 75), 'AAA'] = 0.1

# %%
df
# Out:
#    AAA  BBB  CCC
# 0  0.1   10  100
# 1  5.0   20   50
# 2  0.1   30  -30
# 3  0.1   40  -50

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
aValue = 43.0

df.loc[(df.CCC - aValue).abs().argsort()]
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 0    4   10  100
# 2    6   30  -30
# 3    7   40  -50

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
Crit1 = df.AAA <= 5.5

Crit2 = df.BBB == 10.0

Crit3 = df.CCC > -40.0

# %%
import functools

CritList = [Crit1, Crit2, Crit3]

AllCrit = functools.reduce(lambda x, y: x & y, CritList)

df[AllCrit]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100

# %% [markdown]
# # Selection
#
# DataFrames

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df[(df.AAA <= 6) & (df.index.isin([0, 2, 4]))]
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 2    6   30  -30

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]},
                 index=['foo', 'bar', 'boo', 'kar'])
df
# Out:
#      AAA  BBB  CCC
# foo    4   10  100
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
df.loc['bar':'kar']
# Out:
#      AAA  BBB  CCC
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
df.iloc[0:3]
# Out:
#      AAA  BBB  CCC
# foo    4   10  100
# bar    5   20   50
# boo    6   30  -30

# %%
df.loc['bar':'kar']
# Out:
#      AAA  BBB  CCC
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
data = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
data
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df2 = pd.DataFrame(data=data, index=[1, 2, 3, 4])

df2
# Out:
#    AAA   BBB   CCC
# 1  5.0  20.0  50.0
# 2  6.0  30.0 -30.0
# 3  7.0  40.0 -50.0
# 4  NaN   NaN   NaN

# %%
df2.iloc[1:3]
# Out:
#    AAA   BBB   CCC
# 2  6.0  30.0 -30.0
# 3  7.0  40.0 -50.0

# %%
df2.loc[1:3]
# Out:
#    AAA   BBB   CCC
# 1  5.0  20.0  50.0
# 2  6.0  30.0 -30.0
# 3  7.0  40.0 -50.0

# %%
df = pd.DataFrame({'AAA': [4, 5, 6, 7],
                   'BBB': [10, 20, 30, 40],
                   'CCC': [100, 50, -30, -50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df[~((df.AAA <= 6) & (df.index.isin([0, 2, 4])))]
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 3    7   40  -50

# %% [markdown]
# #                                  New columns

# %%
df = pd.DataFrame({'AAA': [1, 2, 1, 3],
                   'BBB': [1, 1, 2, 2],
                   'CCC': [2, 1, 3, 1]})
df
# Out:
#    AAA  BBB  CCC
# 0    1    1    2
# 1    2    1    1
# 2    1    2    3
# 3    3    2    1

# %%
source_cols = df.columns 

new_cols = [str(x) + "_cat" for x in source_cols]

categories = {1: 'Alpha', 2: 'Beta', 3: 'Charlie'}

df[new_cols] = df[source_cols].applymap(categories.get)

df
# Out:
#    AAA  BBB  CCC  AAA_cat BBB_cat  CCC_cat
# 0    1    1    2    Alpha   Alpha     Beta
# 1    2    1    1     Beta   Alpha    Alpha
# 2    1    2    3    Alpha    Beta  Charlie
# 3    3    2    1  Charlie    Beta    Alpha

# %%
df = pd.DataFrame({'AAA': [1, 1, 1, 2, 2, 2, 3, 3],
                   'BBB': [2, 1, 3, 4, 5, 1, 2, 3]})

df
# Out:
#    AAA  BBB
# 0    1    2
# 1    1    1
# 2    1    3
# 3    2    4
# 4    2    5
# 5    2    1
# 6    3    2
# 7    3    3

# %%
df.loc[df.groupby("AAA")["BBB"].idxmin()]
# Out:
#    AAA  BBB
# 1    1    1
# 5    2    1
# 6    3    2

# %%
df.sort_values(by="BBB").groupby("AAA", as_index=False).first()
# Out:
#    AAA  BBB
# 0    1    1
# 1    2    1
# 2    3    2

# %% [markdown]
# # MultiIndexing

# %%
df = pd.DataFrame({'row': [0, 1, 2],
                   'One_X': [1.1, 1.1, 1.1],
                   'One_Y': [1.2, 1.2, 1.2],
                   'Two_X': [1.11, 1.11, 1.11],
                   'Two_Y': [1.22, 1.22, 1.22]})
df
# Out:
#    row  One_X  One_Y  Two_X  Two_Y
# 0    0    1.1    1.2   1.11   1.22
# 1    1    1.1    1.2   1.11   1.22
# 2    2    1.1    1.2   1.11   1.22

# %%
df = df.set_index('row')

df
# Out:
#      One_X  One_Y  Two_X  Two_Y
# row
# 0      1.1    1.2   1.11   1.22
# 1      1.1    1.2   1.11   1.22
# 2      1.1    1.2   1.11   1.22

# %%
df.columns = pd.MultiIndex.from_tuples([tuple(c)
                                       for c in df.columns])
df
# Out:
#                   l    b
#                   i    e
#                   n    y
#                   e    e
#                   _    r
#                   r  NaN      _
#                   a  NaN      s
#                   c  NaN      h
#                   e  NaN      i
#                 NaN  NaN      f
#                 NaN  NaN      t
#                 NaN  NaN      e
#                 NaN  NaN      d
# Last Gunfighter  10   99    NaN
# Last Gunfighter  10  102   99.0
# Last Gunfighter   8  103  102.0
# Paynter          10  103    NaN
# Paynter          10   88  103.0
# Paynter           8  100   88.0

# %%
df = df.stack(0).reset_index(1)

df
# Out:
#                 level_1      e
#                              y
#                              e
#                              r
#                              _
#                              s
#                              h
#                              i
#                              f
#                              t
#                              e
#                              d
# Last Gunfighter       b   99.0
# Last Gunfighter       b  102.0
# Paynter               b  103.0
# Paynter               b   88.0

# %%
df.columns = ['Sample', 'All_X', 'All_Y']

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-a2d74ce65a11> in <module>
# ----> 1 df.columns = ['Sample', 'All_X', 'All_Y']
#       2
#       3 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5078         try:
#    5079             object.__getattribute__(self, name)
# -> 5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#    5082             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     636
#     637     def _set_axis(self, axis, labels):
# --> 638         self._data.set_axis(axis, labels)
#     639         self._clear_item_cache()
#     640
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     153             raise ValueError(
#     154                 'Length mismatch: Expected axis has {old} elements, new '
# --> 155                 'values have {new} elements'.format(old=old_len, new=new_len))
#     156
#     157         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 2 elements, new values have 3 elements

# %% [markdown]
# # Arithmetic

# %%
cols = pd.MultiIndex.from_tuples([(x, y) for x in ['A', 'B', 'C']
                                 for y in ['O', 'I']])

df = pd.DataFrame(np.random.randn(2, 6), index=['n', 'm'], columns=cols)

df
# Out:
#           A                   B                   C
#           O         I         O         I         O         I
# n -0.972184  0.528878  2.288803  0.622318 -0.294078  0.267744
# m -0.405139 -1.605546 -0.071589 -1.784365  0.290992 -0.840491

# %%
df = df.div(df['C'], level=1)

df
# Out:
#           A                   B              C
#           O         I         O         I    O    I
# n  3.305870  1.975312 -7.782976  2.324300  1.0  1.0
# m -1.392269  1.910247 -0.246018  2.123003  1.0  1.0

# %% [markdown]
# # Slicing

# %%
coords = [('AA', 'one'), ('AA', 'six'), ('BB', 'one'), ('BB', 'two'),
          ('BB', 'six')]

index = pd.MultiIndex.from_tuples(coords)

df = pd.DataFrame([11, 22, 33, 44, 55], index, ['MyData'])

df
# Out:
#         MyData
# AA one      11
#    six      22
# BB one      33
#    two      44
#    six      55

# %%
df.xs('BB', level=0, axis=0)
# Out:
#      MyData
# one      33
# two      44
# six      55

# %%
df.xs('six', level=1, axis=0)
# Out:
#     MyData
# AA      22
# BB      55

# %%
import itertools

index = list(itertools.product(['Ada', 'Quinn', 'Violet'],
                               ['Comp', 'Math', 'Sci']))
 

headr = list(itertools.product(['Exams', 'Labs'], ['I', 'II']))

indx = pd.MultiIndex.from_tuples(index, names=['Student', 'Course'])

cols = pd.MultiIndex.from_tuples(headr)   # Notice these are un-named

data = [[70 + x + y + (x * y) % 3 for x in range(4)] for y in range(9)]

df = pd.DataFrame(data, indx, cols)

df
# Out:
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Ada     Comp      70  71   72  73
#         Math      71  73   75  74
#         Sci       72  75   75  75
# Quinn   Comp      73  74   75  76
#         Math      74  76   78  77
#         Sci       75  78   78  78
# Violet  Comp      76  77   78  79
#         Math      77  79   81  80
#         Sci       78  81   81  81

# %%
All = slice(None)

df.loc['Violet']
# Out:
#        Exams     Labs
#            I  II    I  II
# Course
# Comp      76  77   78  79
# Math      77  79   81  80
# Sci       78  81   81  81

# %%
df.loc[(All, 'Math'), All]
# Out:
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Ada     Math      71  73   75  74
# Quinn   Math      74  76   78  77
# Violet  Math      77  79   81  80

# %%
df.loc[(slice('Ada', 'Quinn'), 'Math'), All]
# Out:
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Ada     Math      71  73   75  74
# Quinn   Math      74  76   78  77

# %%
df.loc[(All, 'Math'), ('Exams')]
# Out:
#                  I  II
# Student Course
# Ada     Math    71  73
# Quinn   Math    74  76
# Violet  Math    77  79

# %%
df.loc[(All, 'Math'), (All, 'II')]
# Out:
#                Exams Labs
#                   II   II
# Student Course
# Ada     Math      73   74
# Quinn   Math      76   77
# Violet  Math      79   80

# %% [markdown]
# # Sorting

# %%
df.sort_values(by=('Labs', 'II'), ascending=False)
# Out:
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Violet  Sci       78  81   81  81
#         Math      77  79   81  80
#         Comp      76  77   78  79
# Quinn   Sci       75  78   78  78
#         Math      74  76   78  77
#         Comp      73  74   75  76
# Ada     Sci       72  75   75  75
#         Math      71  73   75  74
#         Comp      70  71   72  73

# %% [markdown]
# # Levels

# %% [markdown]
# # Missing data

# %%
df = pd.DataFrame(np.random.randn(6, 1),
                  index=pd.date_range('2013-08-01', periods=6, freq='B'),
                  columns=list('A'))

df.loc[df.index[3], 'A'] = np.nan

df
# Out:
#                    A
# 2013-08-01 -0.847733
# 2013-08-02  1.579050
# 2013-08-05  0.085647
# 2013-08-06       NaN
# 2013-08-07 -1.257566
# 2013-08-08  0.258512

# %%
df.reindex(df.index[::-1]).ffill()
# Out:
#                    A
# 2013-08-08  0.258512
# 2013-08-07 -1.257566
# 2013-08-06 -1.257566
# 2013-08-05  0.085647
# 2013-08-02  1.579050
# 2013-08-01 -0.847733

# %% [markdown]
# # Replace

# %% [markdown]
# # Grouping

# %%
df = pd.DataFrame({'animal': 'cat dog cat fish dog cat cat'.split(),
                   'size': list('SSMMMLL'),
                   'weight': [8, 10, 11, 1, 20, 12, 12],
                   'adult': [False] * 5 + [True] * 2})
df
# Out:
#   animal size  weight  adult
# 0    cat    S       8  False
# 1    dog    S      10  False
# 2    cat    M      11  False
# 3   fish    M       1  False
# 4    dog    M      20  False
# 5    cat    L      12   True
# 6    cat    L      12   True

# %%
df.groupby('animal').apply(lambda subf: subf['size'][subf['weight'].idxmax()])
# Out:
# animal
# cat     L
# dog     M
# fish    M
# dtype: object

# %%
gb = df.groupby(['animal'])

gb.get_group('cat')
# Out:
#   animal size  weight  adult
# 0    cat    S       8  False
# 2    cat    M      11  False
# 5    cat    L      12   True
# 6    cat    L      12   True

# %%
def GrowUp(x):
    avg_weight = sum(x[x['size'] == 'S'].weight * 1.5)
    avg_weight += sum(x[x['size'] == 'M'].weight * 1.25)
    avg_weight += sum(x[x['size'] == 'L'].weight)
    avg_weight /= len(x)
    return pd.Series(['L', avg_weight, True],
                     index=['size', 'weight', 'adult'])

expected_df = gb.apply(GrowUp)

expected_df
# Out:
#        size   weight  adult
# animal
# cat       L  12.4375   True
# dog       L  20.0000   True
# fish      L   1.2500   True

# %%
S = pd.Series([i / 100.0 for i in range(1, 11)])

def cum_ret(x, y):
    return x * (1 + y)

def red(x):
    return functools.reduce(cum_ret, x, 1.0)

S.expanding().apply(red, raw=True)
# Out:
# 0    1.010000
# 1    1.030200
# 2    1.061106
# 3    1.103550
# 4    1.158728
# 5    1.228251
# 6    1.314229
# 7    1.419367
# 8    1.547110
# 9    1.701821
# dtype: float64

# %%
df = pd.DataFrame({'A': [1, 1, 2, 2], 'B': [1, -1, 1, 2]})

gb = df.groupby('A')

def replace(g):
    mask = g < 0
    return g.where(mask, g[~mask].mean())

gb.transform(replace)
# Out:
#      B
# 0  1.0
# 1 -1.0
# 2  1.5
# 3  1.5

# %%
df = pd.DataFrame({'code': ['foo', 'bar', 'baz'] * 2,
                   'data': [0.16, -0.21, 0.33, 0.45, -0.59, 0.62],
                   'flag': [False, True] * 3})


code_groups = df.groupby('code')

agg_n_sort_order = code_groups[['data']].transform(sum).sort_values(by='data')

sorted_df = df.loc[agg_n_sort_order.index]

sorted_df
# Out:
#   code  data   flag
# 1  bar -0.21   True
# 4  bar -0.59  False
# 0  foo  0.16  False
# 3  foo  0.45   True
# 2  baz  0.33  False
# 5  baz  0.62   True

# %%
rng = pd.date_range(start="2014-10-07", periods=10, freq='2min')

ts = pd.Series(data=list(range(10)), index=rng)

def MyCust(x):
    if len(x) > 2:
        return x[1] * 1.234
    return pd.NaT

mhc = {'Mean': np.mean, 'Max': np.max, 'Custom': MyCust}

ts.resample("5min").apply(mhc)
# Out:
# Custom  2014-10-07 00:00:00    1.234
#         2014-10-07 00:05:00      NaT
#         2014-10-07 00:10:00    7.404
#         2014-10-07 00:15:00      NaT
# Max     2014-10-07 00:00:00        2
#         2014-10-07 00:05:00        4
#         2014-10-07 00:10:00        7
#         2014-10-07 00:15:00        9
# Mean    2014-10-07 00:00:00        1
#         2014-10-07 00:05:00      3.5
#         2014-10-07 00:10:00        6
#         2014-10-07 00:15:00      8.5
# dtype: object

# %%
ts
# Out:
# 2014-10-07 00:00:00    0
# 2014-10-07 00:02:00    1
# 2014-10-07 00:04:00    2
# 2014-10-07 00:06:00    3
# 2014-10-07 00:08:00    4
# 2014-10-07 00:10:00    5
# 2014-10-07 00:12:00    6
# 2014-10-07 00:14:00    7
# 2014-10-07 00:16:00    8
# 2014-10-07 00:18:00    9
# Freq: 2T, dtype: int64

# %%
df = pd.DataFrame({'Color': 'Red Red Red Blue'.split(),
                   'Value': [100, 150, 50, 50]})
df
# Out:
#   Color  Value
# 0   Red    100
# 1   Red    150
# 2   Red     50
# 3  Blue     50

# %%
df['Counts'] = df.groupby(['Color']).transform(len)

df
# Out:
#   Color  Value  Counts
# 0   Red    100       3
# 1   Red    150       3
# 2   Red     50       3
# 3  Blue     50       1

# %%
df = pd.DataFrame({'line_race': [10, 10, 8, 10, 10, 8],
                   'beyer': [99, 102, 103, 103, 88, 100]},
                  index=['Last Gunfighter', 'Last Gunfighter',
                         'Last Gunfighter', 'Paynter', 'Paynter',
                         'Paynter'])
df
# Out:
#                  line_race  beyer
# Last Gunfighter         10     99
# Last Gunfighter         10    102
# Last Gunfighter          8    103
# Paynter                 10    103
# Paynter                 10     88
# Paynter                  8    100

# %%
df['beyer_shifted'] = df.groupby(level=0)['beyer'].shift(1)

df
# Out:
#                  line_race  beyer  beyer_shifted
# Last Gunfighter         10     99            NaN
# Last Gunfighter         10    102           99.0
# Last Gunfighter          8    103          102.0
# Paynter                 10    103            NaN
# Paynter                 10     88          103.0
# Paynter                  8    100           88.0

# %%
df = pd.DataFrame({'host': ['other', 'other', 'that', 'this', 'this'],
                   'service': ['mail', 'web', 'mail', 'mail', 'web'],
                   'no': [1, 2, 1, 2, 1]}).set_index(['host', 'service'])

mask = df.groupby(level=0).agg('idxmax')

df_count = df.loc[mask['no']].reset_index()

df_count
# Out:
#     host service  no
# 0  other     web   2
# 1   that    mail   1
# 2   this    mail   2

# %%
df = pd.DataFrame([0, 1, 0, 1, 1, 1, 0, 1, 1], columns=['A'])

df.A.groupby((df.A != df.A.shift()).cumsum()).groups
# Out:
# {1: Int64Index([0], dtype='int64'),
#  2: Int64Index([1], dtype='int64'),
#  3: Int64Index([2], dtype='int64'),
#  4: Int64Index([3, 4, 5], dtype='int64'),
#  5: Int64Index([6], dtype='int64'),
#  6: Int64Index([7, 8], dtype='int64')}

# %%
df.A.groupby((df.A != df.A.shift()).cumsum()).cumsum()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    2
# 5    3
# 6    0
# 7    1
# 8    2
# Name: A, dtype: int64

# %% [markdown]
# # Expanding data

# %% [markdown]
# # Splitting

# %%
df = pd.DataFrame(data={'Case': ['A', 'A', 'A', 'B', 'A', 'A', 'B', 'A',
                                 'A'],
                        'Data': np.random.randn(9)})

dfs = list(zip(*df.groupby((1 * (df['Case'] == 'B')).cumsum()
                            .rolling(window=3, min_periods=1).median())))[-1]

dfs[0]
# Out:
#   Case      Data
# 0    A -0.547573
# 1    A -0.022008
# 2    A -0.401596
# 3    B -0.296077

# %% [markdown]
# # Pivot

# %%
df = pd.DataFrame(data={'Province': ['ON', 'QC', 'BC', 'AL', 'AL', 'MN', 'ON'],
                        'City': ['Toronto', 'Montreal', 'Vancouver',
                                 'Calgary', 'Edmonton', 'Winnipeg',
                                 'Windsor'],
                        'Sales': [13, 6, 16, 8, 4, 3, 1]})

table = pd.pivot_table(df, values=['Sales'], index=['Province'],
                      columns=['City'], aggfunc=np.sum, margins=True)

table.stack('City')
# Out:
#                     Sales
# Province City
# AL       All         12.0
#          Calgary      8.0
#          Edmonton     4.0
# BC       All         16.0
#          Vancouver   16.0
# MN       All          3.0
#          Winnipeg     3.0
# ON       All         14.0
#          Toronto     13.0
#          Windsor      1.0
# QC       All          6.0
#          Montreal     6.0
# All      All         51.0
#          Calgary      8.0
#          Edmonton     4.0
#          Montreal     6.0
#          Toronto     13.0
#          Vancouver   16.0
#          Windsor      1.0
#          Winnipeg     3.0

# %%
grades = [48, 99, 75, 80, 42, 80, 72, 68, 36, 78]

df = pd.DataFrame({'ID': ["x%d" % r for r in range(10)],
                  'Gender': ['F', 'M', 'F', 'M', 'F',
                              'M', 'F', 'M', 'M', 'M'],
                  'ExamYear': ['2007', '2007', '2007', '2008', '2008',
                                '2008', '2008', '2009', '2009', '2009'],
                  'Class': ['algebra', 'stats', 'bio', 'algebra',
                            'algebra', 'stats', 'stats', 'algebra',
                            'bio', 'bio'],
                  'Participated': ['yes', 'yes', 'yes', 'yes', 'no',
                                   'yes', 'yes', 'yes', 'yes', 'yes'],
                  'Passed': ['yes' if x > 50 else 'no' for x in grades],
                  'Employed': [True, True, True, False,
                              False, False, False, True, True, False],
                  'Grade': grades})

df.groupby('ExamYear').agg({'Participated': lambda x: x.value_counts()['yes'],
                            'Passed': lambda x: sum(x == 'yes'),
                            'Employed': lambda x: sum(x),
                            'Grade': lambda x: sum(x) / len(x)})
# Out:
#           Participated  Passed  Employed      Grade
# ExamYear
# 2007                 3       2         3  74.000000
# 2008                 3       3         0  68.500000
# 2009                 3       2         2  60.666667

# %%
df = pd.DataFrame({'value': np.random.randn(36)},
                  index=pd.date_range('2011-01-01', freq='M', periods=36))


pd.pivot_table(df, index=df.index.month, columns=df.index.year,
               values='value', aggfunc='sum')
# Out:
#         2011      2012      2013
# 1   0.127079 -0.174914 -1.388993
# 2   0.385146 -0.445895 -0.308567
# 3  -0.756541  1.046282 -1.027235
# 4  -0.227562 -1.028077  1.893872
# 5  -0.444732 -1.398563  1.621208
# 6  -0.356723 -0.719586  0.093077
# 7   1.566014  0.284503  0.862073
# 8  -1.410142 -0.530842  0.313048
# 9   2.079573  0.698730  0.035762
# 10  2.003555 -0.983417 -0.263733
# 11  1.086551  0.019336  0.538734
# 12 -1.060408 -1.483679 -0.557005

# %% [markdown]
# # Apply

# %%
df = pd.DataFrame(data={'A': [[2, 4, 8, 16], [100, 200], [10, 20, 30]],
                        'B': [['a', 'b', 'c'], ['jj', 'kk'], ['ccc']]},
                  index=['I', 'II', 'III'])
 

def SeriesFromSubList(aList):
    return pd.Series(aList)


df_orgz = pd.concat({ind: row.apply(SeriesFromSubList)
                   for ind, row in df.iterrows()})

df_orgz
# Out:
#          0    1    2     3
# I   A    2    4    8  16.0
#     B    a    b    c   NaN
# II  A  100  200  NaN   NaN
#     B   jj   kk  NaN   NaN
# III A   10   20   30   NaN
#     B  ccc  NaN  NaN   NaN

# %%
df = pd.DataFrame(data=np.random.randn(2000, 2) / 10000,
                  index=pd.date_range('2001-01-01', periods=2000),
                  columns=['A', 'B'])
df
# Out:
#                        A             B
# 2001-01-01  4.660184e-05  2.377895e-06
# 2001-01-02  4.094050e-05 -3.176227e-06
# 2001-01-03 -2.969377e-06 -1.070041e-04
# 2001-01-04  6.477906e-05 -4.662647e-05
# 2001-01-05  4.166406e-06  5.266066e-05
# 2001-01-06  3.785062e-05  1.183000e-05
# 2001-01-07 -9.312774e-06 -2.172061e-04
# 2001-01-08  3.504406e-05  9.761568e-05
# 2001-01-09 -2.746050e-05  4.870076e-05
# 2001-01-10 -3.227697e-05 -3.478493e-05
# 2001-01-11  1.135086e-04  2.821004e-05
# 2001-01-12  5.029725e-05  1.822850e-04
# 2001-01-13  1.261080e-04  1.033943e-04
# 2001-01-14 -1.771926e-05  1.786784e-04
# 2001-01-15 -6.320147e-05 -1.138380e-04
# 2001-01-16 -6.076133e-05  3.611226e-05
# 2001-01-17 -7.405656e-05  2.265636e-05
# 2001-01-18  6.466806e-05  1.092173e-04
# 2001-01-19  3.015373e-05 -7.707121e-06
# 2001-01-20 -7.861478e-06  1.731167e-05
# 2001-01-21  2.139286e-05  7.847006e-05
# 2001-01-22 -1.207936e-04  1.643448e-05
# 2001-01-23 -2.638681e-05  9.209103e-07
# 2001-01-24 -3.146096e-05  1.919553e-04
# 2001-01-25  3.968056e-05 -6.812319e-05
# 2001-01-26  2.382672e-05 -8.969993e-05
# 2001-01-27 -6.255483e-05 -1.331680e-04
# 2001-01-28 -4.517840e-05  3.022565e-05
# 2001-01-29 -1.886380e-05 -1.173360e-05
# 2001-01-30  1.541901e-05 -1.465862e-04
# ...                  ...           ...
# 2006-05-25 -4.572863e-05  1.569977e-04
# 2006-05-26 -8.644771e-06 -6.420595e-05
# 2006-05-27 -3.713476e-07 -1.245148e-04
# 2006-05-28 -1.262155e-04 -8.966979e-05
# 2006-05-29  1.240537e-04 -9.019156e-05
# 2006-05-30 -1.245718e-04 -1.680096e-05
# 2006-05-31 -3.074027e-06  9.356338e-05
# 2006-06-01  1.205455e-04  1.089365e-04
# 2006-06-02 -1.629418e-04 -1.654014e-05
# 2006-06-03 -2.208185e-04 -5.574667e-05
# 2006-06-04  8.097187e-05 -8.174996e-05
# 2006-06-05 -2.781947e-05 -1.309606e-05
# 2006-06-06 -1.132696e-05  3.962072e-05
# 2006-06-07 -3.540550e-05 -5.046911e-05
# 2006-06-08 -2.319617e-05 -1.397858e-04
# 2006-06-09 -5.255762e-05 -4.983489e-05
# 2006-06-10  7.723857e-05 -4.174516e-05
# 2006-06-11 -1.924954e-05 -1.337343e-05
# 2006-06-12 -1.796415e-04 -1.498568e-05
# 2006-06-13  3.856140e-05 -3.408023e-05
# 2006-06-14  1.477397e-04  8.589182e-06
# 2006-06-15 -3.790881e-05 -5.525968e-05
# 2006-06-16  4.561968e-05 -4.005225e-05
# 2006-06-17  9.896989e-05 -3.464889e-05
# 2006-06-18  8.983217e-05  1.894792e-06
# 2006-06-19  4.960631e-05  9.758939e-05
# 2006-06-20 -9.329858e-05  1.361037e-04
# 2006-06-21 -3.569719e-05  1.309520e-04
# 2006-06-22  7.394200e-05  2.236984e-04
# 2006-06-23 -1.234747e-04  1.690679e-04
#
# [2000 rows x 2 columns]

# %%
def gm(df, const):
    v = ((((df.A + df.B) + 1).cumprod()) - 1) * const
    return v.iloc[-1]

s = pd.Series({df.index[i]: gm(df.iloc[i:min(i + 51, len(df) - 1)], 5)
              for i in range(len(df) - 50)})
s
# Out:
# 2001-01-01    0.001131
# 2001-01-02    0.001636
# 2001-01-03    0.001908
# 2001-01-04    0.003107
# 2001-01-05    0.003597
# 2001-01-06    0.002974
# 2001-01-07    0.002482
# 2001-01-08    0.004650
# 2001-01-09    0.005023
# 2001-01-10    0.005041
# 2001-01-11    0.004043
# 2001-01-12    0.002250
# 2001-01-13    0.000293
# 2001-01-14   -0.001137
# 2001-01-15   -0.003355
# 2001-01-16   -0.002937
# 2001-01-17   -0.003169
# 2001-01-18   -0.002338
# 2001-01-19   -0.003200
# 2001-01-20   -0.003249
# 2001-01-21   -0.003534
# 2001-01-22   -0.004260
# 2001-01-23   -0.003696
# 2001-01-24   -0.004955
# 2001-01-25   -0.005068
# 2001-01-26   -0.003924
# 2001-01-27   -0.002475
# 2001-01-28   -0.001769
# 2001-01-29   -0.003546
# 2001-01-30   -0.005532
#                 ...
# 2006-04-05    0.007424
# 2006-04-06    0.005525
# 2006-04-07    0.005694
# 2006-04-08    0.004883
# 2006-04-09    0.004992
# 2006-04-10    0.003841
# 2006-04-11    0.004047
# 2006-04-12    0.004915
# 2006-04-13    0.003738
# 2006-04-14    0.001664
# 2006-04-15    0.001772
# 2006-04-16    0.001278
# 2006-04-17    0.000882
# 2006-04-18    0.000340
# 2006-04-19   -0.000881
# 2006-04-20   -0.001584
# 2006-04-21   -0.001399
# 2006-04-22   -0.001659
# 2006-04-23   -0.002237
# 2006-04-24   -0.002356
# 2006-04-25   -0.002205
# 2006-04-26   -0.003037
# 2006-04-27   -0.002318
# 2006-04-28   -0.001810
# 2006-04-29   -0.001418
# 2006-04-30   -0.000523
# 2006-05-01   -0.001191
# 2006-05-02   -0.000040
# 2006-05-03    0.001558
# 2006-05-04    0.000463
# Length: 1950, dtype: float64

# %%
rng = pd.date_range(start='2014-01-01', periods=100)

df = pd.DataFrame({'Open': np.random.randn(len(rng)),
                    'Close': np.random.randn(len(rng)),
                    'Volume': np.random.randint(100, 2000, len(rng))},
                  index=rng)
df
# Out:
#                 Open     Close  Volume
# 2014-01-01  1.527170  0.100194    1437
# 2014-01-02  0.736391 -0.385225    1084
# 2014-01-03 -1.026566 -0.338741     539
# 2014-01-04 -1.139724  0.477860     945
# 2014-01-05  2.524873 -0.786529    1993
# 2014-01-06  0.122539 -0.691611    1105
# 2014-01-07 -0.325686 -0.010479     844
# 2014-01-08  0.259781 -0.381354    1945
# 2014-01-09  0.173616 -0.694144     922
# 2014-01-10  1.434572  0.177494     276
# 2014-01-11  1.337866  1.265811    1439
# 2014-01-12 -0.785704 -0.294031    1363
# 2014-01-13  0.183831  0.757775    1600
# 2014-01-14  0.292077  1.031944     346
# 2014-01-15  0.586464  0.366642    1158
# 2014-01-16 -0.876636 -0.954186    1277
# 2014-01-17 -0.146208  0.917505     218
# 2014-01-18 -0.380981 -0.592327     813
# 2014-01-19  0.703281  1.656250    1950
# 2014-01-20  0.705371 -1.670637    1891
# 2014-01-21 -0.114254  0.039598     868
# 2014-01-22 -0.555320  2.170464    1034
# 2014-01-23  0.995919  0.303117    1810
# 2014-01-24 -0.822518  1.657121    1606
# 2014-01-25 -1.767522  0.563407    1815
# 2014-01-26  0.943518 -1.422184     141
# 2014-01-27  0.410494  1.283471     380
# 2014-01-28  1.105215 -0.909136    1168
# 2014-01-29  0.246587  0.548883     315
# 2014-01-30 -1.026355 -0.918678     202
# ...              ...       ...     ...
# 2014-03-12 -0.631714 -1.650455    1479
# 2014-03-13 -0.340322  0.931732     224
# 2014-03-14 -1.242865 -0.337904     409
# 2014-03-15 -0.001680  0.413137    1423
# 2014-03-16 -1.100760 -1.434485     343
# 2014-03-17 -0.935731 -1.073160    1468
# 2014-03-18 -0.112955 -0.792395     645
# 2014-03-19  0.083517  0.853612     140
# 2014-03-20  0.289031  0.429528    1871
# 2014-03-21  0.227450 -0.197361    1378
# 2014-03-22 -1.633651  0.446632     907
# 2014-03-23  0.548389 -1.187791    1617
# 2014-03-24  1.641507  0.761042    1965
# 2014-03-25  0.410334  0.430503    1688
# 2014-03-26 -0.577081 -0.152889     502
# 2014-03-27  1.788037 -0.238777     985
# 2014-03-28  0.627566 -0.704017     775
# 2014-03-29 -0.030365 -0.435503     210
# 2014-03-30  0.826623  0.294462     790
# 2014-03-31  0.109079  1.319902    1739
# 2014-04-01  1.069414  0.279699    1690
# 2014-04-02 -0.944641  0.409595     747
# 2014-04-03 -0.757888 -0.402486     999
# 2014-04-04  0.408949  0.203640     288
# 2014-04-05 -0.650181  0.461127     806
# 2014-04-06  0.083441 -0.473719    1303
# 2014-04-07  0.065312  0.012101     806
# 2014-04-08  0.446861  1.573755    1119
# 2014-04-09  0.042350  0.331131     419
# 2014-04-10  0.924830  0.636829     532
#
# [100 rows x 3 columns]

# %%
def vwap(bars):
    return ((bars.Close * bars.Volume).sum() / bars.Volume.sum())

window = 5

s = pd.concat([(pd.Series(vwap(df.iloc[i:i + window]),
                index=[df.index[i + window]]))
               for i in range(len(df) - window)])
s.round(2)
# Out:
# 2014-01-06   -0.26
# 2014-01-07   -0.44
# 2014-01-08   -0.38
# 2014-01-09   -0.39
# 2014-01-10   -0.55
# 2014-01-11   -0.41
# 2014-01-12    0.09
# 2014-01-13    0.01
# 2014-01-14    0.36
# 2014-01-15    0.60
# 2014-01-16    0.58
# 2014-01-17    0.07
# 2014-01-18    0.21
# 2014-01-19   -0.19
# 2014-01-20    0.40
# 2014-01-21   -0.23
# 2014-01-22   -0.03
# 2014-01-23    0.28
# 2014-01-24    0.38
# 2014-01-25    0.32
# 2014-01-26    0.91
# 2014-01-27    0.98
# 2014-01-28    0.79
# 2014-01-29    0.57
# 2014-01-30    0.11
# 2014-01-31   -0.36
# 2014-02-01   -0.32
# 2014-02-02   -0.48
# 2014-02-03   -0.18
# 2014-02-04   -0.19
#               ...
# 2014-03-12   -0.06
# 2014-03-13   -0.34
# 2014-03-14   -0.48
# 2014-03-15   -0.56
# 2014-03-16   -0.61
# 2014-03-17   -0.59
# 2014-03-18   -0.36
# 2014-03-19   -0.50
# 2014-03-20   -0.47
# 2014-03-21   -0.37
# 2014-03-22   -0.26
# 2014-03-23    0.11
# 2014-03-24   -0.15
# 2014-03-25    0.07
# 2014-03-26    0.06
# 2014-03-27    0.09
# 2014-03-28   -0.00
# 2014-03-29    0.23
# 2014-03-30   -0.05
# 2014-03-31   -0.22
# 2014-04-01    0.37
# 2014-04-02    0.45
# 2014-04-03    0.62
# 2014-04-04    0.49
# 2014-04-05    0.50
# 2014-04-06    0.18
# 2014-04-07   -0.07
# 2014-04-08   -0.14
# 2014-04-09    0.37
# 2014-04-10    0.37
# Length: 95, dtype: float64

# %% [markdown]
# # Timeseries

# %%
dates = pd.date_range('2000-01-01', periods=5)

dates.to_period(freq='M').to_timestamp()
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-01', '2000-01-01', '2000-01-01',
#                '2000-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# # Merge

# %%
rng = pd.date_range('2000-01-01', periods=6)

df1 = pd.DataFrame(np.random.randn(6, 3), index=rng, columns=['A', 'B', 'C'])

df2 = df1.copy()

# %%
df = df1.append(df2, ignore_index=True)

df
# Out:
#            A         B         C
# 0   0.196545  0.811125  0.059283
# 1  -0.361211  0.399923  0.312959
# 2   3.302254  0.415224  1.314975
# 3  -0.062803  0.216024  1.489227
# 4  -0.228992 -0.583982  0.215967
# 5   1.964884 -0.210261 -0.550684
# 6   0.196545  0.811125  0.059283
# 7  -0.361211  0.399923  0.312959
# 8   3.302254  0.415224  1.314975
# 9  -0.062803  0.216024  1.489227
# 10 -0.228992 -0.583982  0.215967
# 11  1.964884 -0.210261 -0.550684

# %%
df = pd.DataFrame(data={'Area': ['A'] * 5 + ['C'] * 2,
                        'Bins': [110] * 2 + [160] * 3 + [40] * 2,
                        'Test_0': [0, 1, 0, 1, 2, 0, 1],
                        'Data': np.random.randn(7)})
df
# Out:
#   Area  Bins  Test_0      Data
# 0    A   110       0 -0.410980
# 1    A   110       1 -0.177240
# 2    A   160       0  1.159179
# 3    A   160       1  0.257972
# 4    A   160       2 -0.397359
# 5    C    40       0  0.760839
# 6    C    40       1  1.734673

# %%
df['Test_1'] = df['Test_0'] - 1

# %%
pd.merge(df, df, left_on=['Bins', 'Area', 'Test_0'],
         right_on=['Bins', 'Area', 'Test_1'],
         suffixes=('_L', '_R'))
# Out:
#   Area  Bins  Test_0_L    Data_L  Test_1_L  Test_0_R    Data_R  Test_1_R
# 0    A   110         0 -0.410980        -1         1 -0.177240         0
# 1    A   160         0  1.159179        -1         1  0.257972         0
# 2    A   160         1  0.257972         0         2 -0.397359         1
# 3    C    40         0  0.760839        -1         1  1.734673         0

# %% [markdown]
# # Plotting

# %%
# %matplotlib inline

df = pd.DataFrame(
     {'stratifying_var': np.random.uniform(0, 100, 20),
      'price': np.random.normal(100, 5, 20)})

df['quartiles'] = pd.qcut(
    df['stratifying_var'],
    4,
    labels=['0-25%', '25-50%', '50-75%', '75-100%'])

df.boxplot(column='price', by='quartiles')

# %% [markdown]
# # Data In/Out

# %% [markdown]
# # CSV

# %%
for i in range(3):
    data = pd.DataFrame(np.random.randn(10, 4))
    data.to_csv('file_{}.csv'.format(i))
    
files = ['file_0.csv', 'file_1.csv', 'file_2.csv']

result = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

# %%
import glob

import os

files = glob.glob('file_*.csv')

result = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

# %%
i = pd.date_range('20000101', periods=10000)

df = pd.DataFrame({'year': i.year, 'month': i.month, 'day': i.day})

df.head()
# Out:
#    year  month  day
# 0  2000      1    1
# 1  2000      1    2
# 2  2000      1    3
# 3  2000      1    4
# 4  2000      1    5

# %%
# %timeit pd.to_datetime(df.year * 10000 + df.month * 100 + df.day, format='%Y%m%d')
ds = df.apply(lambda x: "%04d%02d%02d" % (x['year'],
                                          x['month'], x['day']), axis=1)
ds.head()

# %timeit pd.to_datetime(ds)
# Out:
# 6.61 ms ± 76 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.12 ms ± 132 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
data = """;;;;
 ;;;;
 ;;;;
 ;;;;
 ;;;;
 ;;;;
;;;;
 ;;;;
 ;;;;
;;;;
date;Param1;Param2;Param4;Param5
    ;m²;°C;m²;m
;;;;
01.01.1990 00:00;1;1;2;3
01.01.1990 01:00;5;3;4;5
01.01.1990 02:00;9;5;6;7
01.01.1990 03:00;13;7;8;9
01.01.1990 04:00;17;9;10;11
01.01.1990 05:00;21;11;12;13
"""

# %%
from io import StringIO

pd.read_csv(StringIO(data), sep=';', skiprows=[11, 12],
           index_col=0, parse_dates=True, header=10)
# Out:
#                      Param1  Param2  Param4  Param5
# date
# 1990-01-01 00:00:00       1       1       2       3
# 1990-01-01 01:00:00       5       3       4       5
# 1990-01-01 02:00:00       9       5       6       7
# 1990-01-01 03:00:00      13       7       8       9
# 1990-01-01 04:00:00      17       9      10      11
# 1990-01-01 05:00:00      21      11      12      13

# %%
pd.read_csv(StringIO(data), sep=';', header=10, nrows=10).columns

Index(['date', 'Param1', 'Param2', 'Param4', 'Param5'], dtype='object')

columns = pd.read_csv(StringIO(data), sep=';', header=10, nrows=10).columns

pd.read_csv(StringIO(data), sep=';', index_col=0,
            header=12, parse_dates=True, names=columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-df3de468d36c> in <module>
#       1 pd.read_csv(StringIO(data), sep=';', header=10, nrows=10).columns
#       2
# ----> 3 Index(['date', 'Param1', 'Param2', 'Param4', 'Param5'], dtype='object')
#       4
#       5 columns = pd.read_csv(StringIO(data), sep=';', header=10, nrows=10).columns
#
# NameError: name 'Index' is not defined

# %%
df = pd.DataFrame(np.random.randn(8, 3))

store = pd.HDFStore('test.h5')

store.put('df', df)

store.get_storer('df').attrs.my_attribute = {'A': 10}

store.get_storer('df').attrs.my_attribute
# Out:
# {'A': 10}

# %% [markdown]
# # Computation

# %%
df = pd.DataFrame(np.random.random(size=(100, 5)))

corr_mat = df.corr()

mask = np.tril(np.ones_like(corr_mat, dtype=np.bool), k=-1)

corr_mat.where(mask)
# Out:
#           0         1         2         3   4
# 0       NaN       NaN       NaN       NaN NaN
# 1 -0.022833       NaN       NaN       NaN NaN
# 2  0.000738 -0.063488       NaN       NaN NaN
# 3  0.110333 -0.050325 -0.044555       NaN NaN
# 4 -0.013101  0.100511 -0.066899 -0.130321 NaN

# %%
def distcorr(x, y):
    n = len(x)
    a = np.zeros(shape=(n, n))
    b = np.zeros(shape=(n, n))
    for i in range(n):
        for j in range(i + 1, n):
            a[i, j] = abs(x[i] - x[j])
            b[i, j] = abs(y[i] - y[j])
    a += a.T
    b += b.T
    a_bar = np.vstack([np.nanmean(a, axis=0)] * n)
    b_bar = np.vstack([np.nanmean(b, axis=0)] * n)
    A = a - a_bar - a_bar.T + np.full(shape=(n, n), fill_value=a_bar.mean())
    B = b - b_bar - b_bar.T + np.full(shape=(n, n), fill_value=b_bar.mean())
    cov_ab = np.sqrt(np.nansum(A * B)) / n
    std_a = np.sqrt(np.sqrt(np.nansum(A**2)) / n)
    std_b = np.sqrt(np.sqrt(np.nansum(B**2)) / n)
    return cov_ab / std_a / std_b

df = pd.DataFrame(np.random.normal(size=(100, 3)))

df.corr(method=distcorr)
# Out:
#           0         1         2
# 0  1.000000  0.258666  0.134202
# 1  0.258666  1.000000  0.200558
# 2  0.134202  0.200558  1.000000

# %% [markdown]
# # Timedeltas

# %%
import datetime

s = pd.Series(pd.date_range('2012-1-1', periods=3, freq='D'))

s - s.max()
# Out:
# 0   -2 days
# 1   -1 days
# 2    0 days
# dtype: timedelta64[ns]

# %%
s.max() - s
# Out:
# 0   2 days
# 1   1 days
# 2   0 days
# dtype: timedelta64[ns]

# %%
s - datetime.datetime(2011, 1, 1, 3, 5)
# Out:
# 0   364 days 20:55:00
# 1   365 days 20:55:00
# 2   366 days 20:55:00
# dtype: timedelta64[ns]

# %%
s + datetime.timedelta(minutes=5)
# Out:
# 0   2012-01-01 00:05:00
# 1   2012-01-02 00:05:00
# 2   2012-01-03 00:05:00
# dtype: datetime64[ns]

# %%
datetime.datetime(2011, 1, 1, 3, 5) - s
# Out:
# 0   -365 days +03:05:00
# 1   -366 days +03:05:00
# 2   -367 days +03:05:00
# dtype: timedelta64[ns]

# %%
datetime.timedelta(minutes=5) + s
# Out:
# 0   2012-01-01 00:05:00
# 1   2012-01-02 00:05:00
# 2   2012-01-03 00:05:00
# dtype: datetime64[ns]

# %%
deltas = pd.Series([datetime.timedelta(days=i) for i in range(3)])

df = pd.DataFrame({'A': s, 'B': deltas})

df
# Out:
#            A      B
# 0 2012-01-01 0 days
# 1 2012-01-02 1 days
# 2 2012-01-03 2 days

# %%
df['New Dates'] = df['A'] + df['B']

df['Delta'] = df['A'] - df['New Dates']

df
# Out:
#            A      B  New Dates   Delta
# 0 2012-01-01 0 days 2012-01-01  0 days
# 1 2012-01-02 1 days 2012-01-03 -1 days
# 2 2012-01-03 2 days 2012-01-05 -2 days

# %%
df.dtypes
# Out:
# A             datetime64[ns]
# B            timedelta64[ns]
# New Dates     datetime64[ns]
# Delta        timedelta64[ns]
# dtype: object

# %%
y = s - s.shift()

y
# Out:
# 0      NaT
# 1   1 days
# 2   1 days
# dtype: timedelta64[ns]

# %%
y[1] = np.nan

y
# Out:
# 0      NaT
# 1      NaT
# 2   1 days
# dtype: timedelta64[ns]

# %%
def set_axis_alias(cls, axis, alias):
    if axis not in cls._AXIS_NUMBERS:
        raise Exception("invalid axis [%s] for alias [%s]" % (axis, alias))
    cls._AXIS_ALIASES[alias] = axis

# %%
def clear_axis_alias(cls, axis, alias):
    if axis not in cls._AXIS_NUMBERS:
        raise Exception("invalid axis [%s] for alias [%s]" % (axis, alias))
    cls._AXIS_ALIASES.pop(alias, None)

# %%
set_axis_alias(pd.DataFrame, 'columns', 'myaxis2')

df2 = pd.DataFrame(np.random.randn(3, 2), columns=['c1', 'c2'],
                   index=['i1', 'i2', 'i3'])

df2.sum(axis='myaxis2')
# Out:
# i1    1.769605
# i2   -0.616484
# i3   -0.102318
# dtype: float64

# %% [markdown]
# # Creating example data

# %%
def expand_grid(data_dict):
    rows = itertools.product(*data_dict.values())
    return pd.DataFrame.from_records(rows, columns=data_dict.keys())

df = expand_grid({'height': [60, 70],
                  'weight': [100, 140, 180],
                  'sex': ['Male', 'Female']})
df
# Out:
#     height  weight     sex
# 0       60     100    Male
# 1       60     100  Female
# 2       60     140    Male
# 3       60     140  Female
# 4       60     180    Male
# 5       60     180  Female
# 6       70     100    Male
# 7       70     100  Female
# 8       70     140    Male
# 9       70     140  Female
# 10      70     180    Male
# 11      70     180  Female
